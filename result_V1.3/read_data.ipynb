# %%
import pickle

# %%
with open('ip_ban.pickle', 'rb') as file:
    ip_ban_list = pickle.load(file)
with open('ip_dict.pickle', 'rb') as file:
    ip_dict = pickle.load(file)
with open('win_score.pickle', 'rb') as file:
    win_score = pickle.load(file)
with open('lose_score.pickle', 'rb') as file:
    lose_score = pickle.load(file)

print(len(ip_ban_list))
print(len(ip_dict))
print(len(win_score))
print(len(lose_score))
# Out:
# 7668
# 8399
# 90
# 90

# %%
ip_ban_list
# Out:
# {'112.81.59.183',
#  '175.154.175.193',
#  '2409:893d:50a:e40:cf5:75ff:fe36:cdfe',
#  '223.73.111.159',
#  '240e:473:830:5d70:8c29:d9ff:fe0d:82c',
#  '14.221.237.85',
#  '43.250.200.78',
#  '221.216.102.165',
#  '171.113.253.244',
#  '223.107.209.217',
#  '117.136.52.220',
#  '80.181.245.96',
#  '120.229.235.11',
#  '39.144.156.30',
#  '121.226.157.185',
#  '223.104.122.121',
#  '223.104.195.64',
#  '112.10.130.65',
#  '14.150.68.197',
#  '113.251.159.61',
#  '2001:da8:100a:6000::c:9442',
#  '115.27.216.245',
#  '2408:8417:1af0:41a3:14f8:8d2c:52bd:3946',
#  '117.136.79.205',
#  '58.247.22.200',
#  '183.151.206.177',
#  '222.95.239.45',
#  '223.104.151.209',
#  '125.106.232.65',
#  '39.144.28.56',
#  '117.136.36.145',
#  '14.135.160.100',
#  '106.86.109.57',
#  '240e:468:e223:964a:be21:7552:b988:422f',
#  '123.165.52.153',
#  '115.61.176.49',
#  '43.225.208.246',
#  '223.104.159.95',
#  '111.167.3.186',
#  '112.28.229.154',
#  '111.45.33.200',
#  '1.193.59.208',
#  '111.205.21.123',
# ...

# %%
ip_dict
# Out:
# {'125.62.3.239': 24,
#  '39.79.74.78': 40,
#  '171.113.244.99': 50,
#  '195.194.24.24': 47,
#  '223.246.187.177': 2,
#  '110.191.98.255': 10,
#  '49.93.111.122': 33,
#  '139.215.45.32': 11,
#  '180.98.173.126': 50,
#  '112.3.195.239': 50,
#  '1.174.88.145': 39,
#  '61.140.185.40': 20,
#  '43.227.137.30': 2,
#  '49.65.248.113': 48,
#  '195.213.226.25': 29,
#  '39.144.145.131': 19,
#  '122.192.15.109': 4,
#  '14.25.174.158': 15,
#  '59.42.21.235': 21,
#  '113.118.145.46': 32,
#  '220.200.125.171': 49,
#  '36.23.158.62': 12,
#  '58.246.155.87': 4,
#  '114.93.221.25': 36,
#  '218.57.69.132': 50,
#  '222.201.156.74': 30,
#  '112.96.63.115': 9,
#  '183.38.68.233': 6,
#  '113.200.58.88': 48,
#  '117.39.200.21': 34,
#  '140.224.215.242': 5,
#  '112.80.192.81': 18,
#  '64.231.232.43': 32,
#  '183.167.31.195': 36,
#  '112.10.234.35': 49,
#  '111.9.206.100': 5,
#  '120.245.134.196': 47,
#  '49.93.110.101': 50,
#  '120.242.209.158': 26,
#  '39.144.154.200': 42,
#  '39.144.168.25': 34,
# ...

# %%
win_score
# Out:
# [4484.480000001751,
#  981.0199999999772,
#  6071.500000002878,
#  9331.550000004661,
#  3291.9700000009716,
#  3441.130000001173,
#  9220.750000004848,
#  5703.620000002592,
#  8878.810000004512,
#  6656.560000003191,
#  3062.230000000399,
#  2223.5900000000074,
#  4468.690000001815,
#  1434.5999999999633,
#  3964.660000001611,
#  7666.840000004094,
#  5031.880000002132,
#  5698.970000002719,
#  7045.5500000036245,
#  10784.640000005735,
#  10351.90000000553,
#  3382.5200000011228,
#  7109.820000003786,
#  2010.0899999999524,
#  4119.250000001565,
#  10402.100000005436,
#  3919.700000001233,
#  2250.790000000025,
#  12554.610000006547,
#  5124.190000002444,
#  6580.160000003034,
#  1688.1999999999564,
#  5855.970000002547,
#  1596.6799999999619,
#  2258.3000000000134,
#  2554.2600000001635,
#  3190.7100000008973,
#  2390.950000000096,
#  6045.2400000030775,
#  7098.980000003357,
#  10565.28000000532,
#  2192.3900000000003,
#  1301.2299999999675,
#  2939.2000000003454,
# ...

# %%
lose_score
# Out:
# [7688.010000003907,
#  11070.170000005892,
#  6088.400000002918,
#  3539.6500000011574,
#  8750.780000004466,
#  8380.950000004259,
#  3397.4400000009464,
#  6534.12000000316,
#  3676.6200000012786,
#  5696.930000002677,
#  8922.690000004559,
#  9618.530000004897,
#  7636.0600000037575,
#  10393.620000005485,
#  7934.470000003832,
#  4661.330000001717,
#  6989.860000003539,
#  6457.270000002943,
#  5214.340000002274,
#  2390.7900000000627,
#  2601.240000000185,
#  8498.11000000415,
#  4993.140000001994,
#  10085.910000005197,
#  8078.460000004021,
#  2561.8000000001352,
#  8108.73000000443,
#  9684.4300000051,
#  1202.1199999999794,
#  7072.840000003254,
#  5787.700000002765,
#  10234.500000005295,
#  6523.050000003259,
#  10361.600000005425,
#  9631.080000005073,
#  9311.050000004892,
#  8875.9400000045,
#  9361.000000004886,
#  6022.920000002662,
#  5358.900000002469,
#  2763.920000000262,
#  9486.830000004971,
#  10361.330000005451,
#  8911.51000000468,
#  2414.5700000001007,
# ...
